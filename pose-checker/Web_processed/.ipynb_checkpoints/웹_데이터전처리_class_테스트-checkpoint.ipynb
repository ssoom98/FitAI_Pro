# %%
import cv2
import numpy as np
import json
import tarfile
import shutil
import tensorflow as tf
import tensorflow_hub as hub
import os
import matplotlib.pyplot as plt
from ultralytics import YOLO  # YOLOv8 라이브러리 (예시)

class ImageProcessor:

    # 클래스 변수 추가
    m = (255, 0, 255)
    c = (0, 255, 255)
    y = (255, 255, 0)

    KEYPOINT_DICT = {
        'nose': 0, 'left_eye': 1, 'right_eye': 2, 'left_ear': 3, 'right_ear': 4,
        'left_shoulder': 5, 'right_shoulder': 6, 'left_elbow': 7, 'right_elbow': 8,
        'left_wrist': 9, 'right_wrist': 10, 'left_hip': 11, 'right_hip': 12,
        'left_knee': 13, 'right_knee': 14, 'left_ankle': 15, 'right_ankle': 16
    }

    KEYPOINT_EDGES = {
        (0, 1): m, (0, 2): c, (1, 3): m, (2, 4): c, (0, 5): m, (0, 6): c,
        (5, 7): m, (7, 9): m, (6, 8): c, (8, 10): c, (5, 6): y, (5, 11): m,
        (6, 12): c, (11, 12): y, (11, 13): m, (13, 15): m, (12, 14): c, (14, 16): c
    }

    # MoveNet 모델 로드 (클래스 변수로 유지)
    module = hub.load("https://www.kaggle.com/models/google/movenet/TensorFlow2/singlepose-thunder/4")
    movenet = module.signatures['serving_default']

    def __init__(self, model_path="yolov8n.pt"):
        self.model = YOLO(model_path)  # YOLOv8 모델 로드

    def detect_pose(self, image):
        """MoveNet을 사용하여 포즈 감지"""
        input_image = tf.image.resize(image, [256, 256])
        input_image = tf.expand_dims(input_image, axis=0)
        input_image = tf.cast(input_image, dtype=tf.int32)
        outputs = self.movenet(input_image)
        keypoints = outputs['output_0'].numpy()
        return keypoints

    def extract_middle_32_frames(self, video_path, output_dir, confidence_threshold=0.5, bg_color=(0, 0, 0)):
        """
        동영상 파일에서 초당 1프레임씩 추출한 후, 전체 추출된 프레임 중 가운데 32프레임에 대해
        YOLOv8 FHD 크롭(detect_person_yolov8_fhd_crop_from_frame)을 적용하여 지정한 output_dir에 저장합니다.
        """
        cap = cv2.VideoCapture(video_path)
        if not cap.isOpened():
            print("비디오 파일을 열 수 없습니다.")
            return

        fps = cap.get(cv2.CAP_PROP_FPS)
        frame_interval = int(round(fps))
        frames = []
        frame_index = 0

        # 초당 1프레임씩 추출하여 리스트에 저장
        while True:
            ret, frame = cap.read()
            if not ret:
                break
            if frame_index % frame_interval == 0:
                frames.append(frame)
            frame_index += 1

        cap.release()

        total_frames = len(frames)
        if total_frames < 32:
            print(f"추출된 프레임 수({total_frames})가 32보다 적습니다.")
            return

        start_idx = (total_frames - 32) // 2
        end_idx = start_idx + 32

        if not os.path.exists(output_dir):
            os.makedirs(output_dir)

        for i in range(start_idx, end_idx):
            frame = frames[i]
            # 추출된 프레임에 대해 사람 객체 FHD 크롭 적용
            processed_frame = self.detect_person_yolov8_fhd_crop_from_frame(frame, confidence_threshold, bg_color)
            if processed_frame is not None:
                video_name = os.path.splitext(os.path.basename(video_path))[0]
                output_path = os.path.join(output_dir, f"{video_name}_frame_{i:04d}.jpg")
                cv2.imwrite(output_path, processed_frame)
                print(f"저장된 프레임: {output_path}")
            else:
                print(f"프레임 {i:04d}에서 사람이 탐지되지 않았습니다.")

    def detect_person_yolov8_fhd_crop_from_frame(self, frame, confidence_threshold=0.5, bg_color=(0, 0, 0)):
        """
        이미지 배열(frame)을 받아 YOLOv8으로 사람 객체를 탐지한 후,
        탐지된 사람의 중심을 기준으로 1920×1080 크기의 영역을 추출합니다.
        만약 추출 영역이 원본 이미지 범위를 벗어난다면, 부족한 부분은 bg_color(기본: 검은색)으로 채웁니다.
        탐지에 실패하면 None을 반환합니다.
        """
        H, W, _ = frame.shape
        results = self.model(frame)[0]
    
        best_confidence = 0.0
        best_box = None
    
        for box in results.boxes:
            # 바운딩 박스 좌표를 정수로 변환
            x1, y1, x2, y2 = map(int, box.xyxy[0])
            confidence = box.conf[0].item()
            class_id = int(box.cls[0].item())
            if class_id == 0 and confidence > confidence_threshold:
                if confidence > best_confidence:
                    best_confidence = confidence
                    best_box = (x1, y1, x2, y2)
    
        if best_box is None:
            print("사람이 탐지되지 않았습니다.")
            return None
    
        # 탐지된 사람의 중심 좌표 계산
        x1, y1, x2, y2 = best_box
        center_x = (x1 + x2) / 2
        center_y = (y1 + y2) / 2
    
        # FHD 해상도 (1920x1080)
        target_w, target_h = 1920, 1080
    
        # 사람의 중심을 기준으로 FHD 영역의 경계 계산
        left = int(round(center_x - target_w / 2))
        top = int(round(center_y - target_h / 2))
        right = left + target_w
        bottom = top + target_h
    
        # FHD 크기의 배경 이미지 생성 (배경색: bg_color)
        output_img = np.full((target_h, target_w, 3), bg_color, dtype=np.uint8)
    
        # 원본 이미지와 FHD 영역의 겹치는 부분 계산
        src_x1 = max(0, left)
        src_y1 = max(0, top)
        src_x2 = min(W, right)
        src_y2 = min(H, bottom)
    
        # output_img에서 복사할 위치 계산 (만약 crop 영역이 이미지 범위를 벗어나면 그만큼 offset)
        dst_x1 = max(0, -left)
        dst_y1 = max(0, -top)
        dst_x2 = dst_x1 + (src_x2 - src_x1)
        dst_y2 = dst_y1 + (src_y2 - src_y1)
    
        # 겹치는 영역 복사
        output_img[dst_y1:dst_y2, dst_x1:dst_x2] = frame[src_y1:src_y2, src_x1:src_x2]
    
        return output_img

    def draw_pose(self, image, keypoints, confidence_threshold=0.3):
        """
        원본 이미지 위에 MoveNet으로 검출된 keypoints를 점과 선으로 시각화합니다.
        
        Parameters:
            image: 원본 이미지 (RGB)
            keypoints: detect_pose 함수의 출력 (shape: [1, 1, 17, 3])
            confidence_threshold: keypoint 신뢰도 임계값
        """
        # keypoints 배열을 (17,3) 형태로 변환 (y, x, conf)
        keypoints = keypoints[0, 0, :, :]
        H, W, _ = image.shape

        plt.figure(figsize=(10, 10))
        plt.imshow(image)

        # keypoint 점 그리기
        for i, kp in enumerate(keypoints):
            y, x, conf = kp  # 출력 순서는 [y, x, confidence]
            if conf > confidence_threshold:
                plt.scatter(x * W, y * H, s=100, c='red', marker='o')
                plt.text(x * W, y * H, f'{i}', color='white', fontsize=12)

        # KEYPOINT_EDGES에 정의된 선 그리기
        for edge, color in self.KEYPOINT_EDGES.items():
            i1, i2 = edge
            kp1 = keypoints[i1]
            kp2 = keypoints[i2]
            if kp1[2] > confidence_threshold and kp2[2] > confidence_threshold:
                x1, y1 = kp1[1] * W, kp1[0] * H
                x2, y2 = kp2[1] * W, kp2[0] * H
                # 색상은 0~255 범위이므로, 255로 나눠서 0~1 범위로 변환
                plt.plot([x1, x2], [y1, y2], color=np.array(color)/255.0, linewidth=2)

# %%
# 인스턴스 생성 (YOLOv8 모델 경로를 실제 경로로 수정)
processor = ImageProcessor(model_path="D:/KHH/team_project/yolov8n.pt")
processor.extract_middle_32_frames("D:/KHH/team_project/test.mp4", "D:/KHH/team_project/test/")
# Out:
# 0: 640x640 2 persons, 1 airplane, 1 frisbee, 50.6ms
# Speed: 4.0ms preprocess, 50.6ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
# 저장된 프레임: D:/KHH/team_project/test/test_frame_0019.jpg
#
# 0: 640x640 1 person, 46.2ms
# Speed: 3.1ms preprocess, 46.2ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
# 저장된 프레임: D:/KHH/team_project/test/test_frame_0020.jpg
#
# 0: 640x640 1 person, 2 airplanes, 43.0ms
# Speed: 3.8ms preprocess, 43.0ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
# 저장된 프레임: D:/KHH/team_project/test/test_frame_0021.jpg
#
# 0: 640x640 1 person, 2 airplanes, 1 clock, 44.8ms
# Speed: 3.3ms preprocess, 44.8ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
# 저장된 프레임: D:/KHH/team_project/test/test_frame_0022.jpg
#
# 0: 640x640 1 person, 2 airplanes, 1 clock, 43.2ms
# Speed: 3.6ms preprocess, 43.2ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
# 저장된 프레임: D:/KHH/team_project/test/test_frame_0023.jpg
#
# 0: 640x640 1 person, 1 airplane, 44.3ms
# Speed: 3.5ms preprocess, 44.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
# 저장된 프레임: D:/KHH/team_project/test/test_frame_0024.jpg
#
# 0: 640x640 1 person, 1 airplane, 41.9ms
# Speed: 3.5ms preprocess, 41.9ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
# 저장된 프레임: D:/KHH/team_project/test/test_frame_0025.jpg
#
# 0: 640x640 2 persons, 1 airplane, 1 frisbee, 1 clock, 44.2ms
# Speed: 2.6ms preprocess, 44.2ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
# 저장된 프레임: D:/KHH/team_project/test/test_frame_0026.jpg
#
# 0: 640x640 2 persons, 1 airplane, 1 clock, 51.5ms
# Speed: 3.4ms preprocess, 51.5ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
# 사람이 탐지되지 않았습니다.
# 프레임 0027에서 사람이 탐지되지 않았습니다.
#
# 0: 640x640 1 person, 1 airplane, 47.4ms
# Speed: 5.7ms preprocess, 47.4ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
# 저장된 프레임: D:/KHH/team_project/test/test_frame_0028.jpg
#
# 0: 640x640 1 person, 2 airplanes, 45.2ms
# Speed: 2.9ms preprocess, 45.2ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
# 저장된 프레임: D:/KHH/team_project/test/test_frame_0029.jpg
#
# 0: 640x640 2 persons, 1 airplane, 1 clock, 43.0ms
# Speed: 3.1ms preprocess, 43.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
# 사람이 탐지되지 않았습니다.
# 프레임 0030에서 사람이 탐지되지 않았습니다.
#
# 0: 640x640 2 persons, 1 airplane, 1 clock, 42.8ms
# Speed: 3.8ms preprocess, 42.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
# 저장된 프레임: D:/KHH/team_project/test/test_frame_0031.jpg
#
# 0: 640x640 1 person, 1 airplane, 44.8ms
# Speed: 3.5ms preprocess, 44.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
# 저장된 프레임: D:/KHH/team_project/test/test_frame_0032.jpg
#
# 0: 640x640 1 person, 1 airplane, 1 clock, 46.8ms
# Speed: 3.8ms preprocess, 46.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
# 저장된 프레임: D:/KHH/team_project/test/test_frame_0033.jpg
#
# 0: 640x640 1 person, 1 airplane, 1 clock, 44.6ms
# Speed: 2.8ms preprocess, 44.6ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
# 저장된 프레임: D:/KHH/team_project/test/test_frame_0034.jpg
#
# 0: 640x640 1 person, 1 airplane, 1 chair, 44.7ms
# Speed: 3.8ms preprocess, 44.7ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
# 저장된 프레임: D:/KHH/team_project/test/test_frame_0035.jpg
#
# 0: 640x640 1 person, 1 airplane, 1 chair, 46.4ms
# Speed: 3.3ms preprocess, 46.4ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
# 저장된 프레임: D:/KHH/team_project/test/test_frame_0036.jpg
#
# 0: 640x640 1 person, 1 airplane, 1 clock, 44.6ms
# Speed: 3.7ms preprocess, 44.6ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
# 저장된 프레임: D:/KHH/team_project/test/test_frame_0037.jpg
#
# 0: 640x640 1 person, 1 airplane, 1 clock, 44.7ms
# Speed: 3.1ms preprocess, 44.7ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
# 저장된 프레임: D:/KHH/team_project/test/test_frame_0038.jpg
#
# 0: 640x640 1 person, 1 airplane, 1 clock, 43.2ms
# Speed: 3.5ms preprocess, 43.2ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
# 저장된 프레임: D:/KHH/team_project/test/test_frame_0039.jpg
#
# 0: 640x640 1 person, 1 airplane, 1 clock, 43.6ms
# Speed: 3.3ms preprocess, 43.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# 저장된 프레임: D:/KHH/team_project/test/test_frame_0040.jpg
#
# 0: 640x640 1 person, 2 airplanes, 41.3ms
# Speed: 3.7ms preprocess, 41.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
# 저장된 프레임: D:/KHH/team_project/test/test_frame_0041.jpg
#
# 0: 640x640 2 persons, 2 airplanes, 1 clock, 44.3ms
# Speed: 3.8ms preprocess, 44.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
# 저장된 프레임: D:/KHH/team_project/test/test_frame_0042.jpg
#
# 0: 640x640 2 persons, 1 airplane, 1 clock, 43.5ms
# Speed: 3.5ms preprocess, 43.5ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
# 저장된 프레임: D:/KHH/team_project/test/test_frame_0043.jpg
#
# 0: 640x640 1 person, 1 airplane, 1 clock, 41.1ms
# Speed: 2.7ms preprocess, 41.1ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
# 저장된 프레임: D:/KHH/team_project/test/test_frame_0044.jpg
#
# 0: 640x640 1 person, 1 airplane, 1 clock, 66.1ms
# Speed: 7.7ms preprocess, 66.1ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
# 저장된 프레임: D:/KHH/team_project/test/test_frame_0045.jpg
#
# 0: 640x640 1 person, 1 airplane, 1 toilet, 49.9ms
# Speed: 4.6ms preprocess, 49.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
# 저장된 프레임: D:/KHH/team_project/test/test_frame_0046.jpg
#
# 0: 640x640 1 person, 2 airplanes, 49.7ms
# Speed: 4.2ms preprocess, 49.7ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
# 저장된 프레임: D:/KHH/team_project/test/test_frame_0047.jpg
#
# 0: 640x640 3 persons, 1 airplane, 1 clock, 46.4ms
# Speed: 3.8ms preprocess, 46.4ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
# 사람이 탐지되지 않았습니다.
# 프레임 0048에서 사람이 탐지되지 않았습니다.
#
# 0: 640x640 1 person, 1 airplane, 1 clock, 44.9ms
# Speed: 3.6ms preprocess, 44.9ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
# 저장된 프레임: D:/KHH/team_project/test/test_frame_0049.jpg
#
# 0: 640x640 1 person, 1 airplane, 1 clock, 41.8ms
# Speed: 3.5ms preprocess, 41.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
# 저장된 프레임: D:/KHH/team_project/test/test_frame_0050.jpg

# %%
processor.extract_middle_32_frames("D:/KHH/team_project/test_2.mp4", "D:/KHH/team_project/test/")
# Out:
# 0: 640x384 2 persons, 1 airplane, 36.0ms
# Speed: 3.2ms preprocess, 36.0ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 저장된 프레임: D:/KHH/team_project/test/test_2_frame_0001.jpg
#
# 0: 640x384 2 persons, 32.7ms
# Speed: 2.6ms preprocess, 32.7ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
# 저장된 프레임: D:/KHH/team_project/test/test_2_frame_0002.jpg
#
# 0: 640x384 1 person, 29.7ms
# Speed: 2.4ms preprocess, 29.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
# 저장된 프레임: D:/KHH/team_project/test/test_2_frame_0003.jpg
#
# 0: 640x384 1 person, 1 skateboard, 1 clock, 31.3ms
# Speed: 3.0ms preprocess, 31.3ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
# 저장된 프레임: D:/KHH/team_project/test/test_2_frame_0004.jpg
#
# 0: 640x384 1 person, 1 clock, 30.6ms
# Speed: 2.6ms preprocess, 30.6ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
# 저장된 프레임: D:/KHH/team_project/test/test_2_frame_0005.jpg
#
# 0: 640x384 1 person, 1 skateboard, 2 clocks, 30.4ms
# Speed: 3.0ms preprocess, 30.4ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
# 저장된 프레임: D:/KHH/team_project/test/test_2_frame_0006.jpg
#
# 0: 640x384 1 person, 1 skateboard, 1 clock, 30.6ms
# Speed: 2.6ms preprocess, 30.6ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
# 저장된 프레임: D:/KHH/team_project/test/test_2_frame_0007.jpg
#
# 0: 640x384 1 person, 1 skateboard, 1 clock, 30.9ms
# Speed: 2.5ms preprocess, 30.9ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
# 저장된 프레임: D:/KHH/team_project/test/test_2_frame_0008.jpg
#
# 0: 640x384 1 person, 32.0ms
# Speed: 2.6ms preprocess, 32.0ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
# 저장된 프레임: D:/KHH/team_project/test/test_2_frame_0009.jpg
#
# 0: 640x384 1 person, 29.5ms
# Speed: 2.5ms preprocess, 29.5ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
# 저장된 프레임: D:/KHH/team_project/test/test_2_frame_0010.jpg
#
# 0: 640x384 1 person, 1 clock, 27.9ms
# Speed: 2.2ms preprocess, 27.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
# 저장된 프레임: D:/KHH/team_project/test/test_2_frame_0011.jpg
#
# 0: 640x384 1 person, 31.0ms
# Speed: 2.5ms preprocess, 31.0ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
# 저장된 프레임: D:/KHH/team_project/test/test_2_frame_0012.jpg
#
# 0: 640x384 1 person, 28.5ms
# Speed: 2.9ms preprocess, 28.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# 저장된 프레임: D:/KHH/team_project/test/test_2_frame_0013.jpg
#
# 0: 640x384 1 person, 30.3ms
# Speed: 2.9ms preprocess, 30.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
# 저장된 프레임: D:/KHH/team_project/test/test_2_frame_0014.jpg
#
# 0: 640x384 1 person, 1 clock, 31.5ms
# Speed: 2.5ms preprocess, 31.5ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 저장된 프레임: D:/KHH/team_project/test/test_2_frame_0015.jpg
#
# 0: 640x384 1 person, 40.5ms
# Speed: 6.3ms preprocess, 40.5ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
# 저장된 프레임: D:/KHH/team_project/test/test_2_frame_0016.jpg
#
# 0: 640x384 1 person, 29.8ms
# Speed: 2.6ms preprocess, 29.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
# 저장된 프레임: D:/KHH/team_project/test/test_2_frame_0017.jpg
#
# 0: 640x384 1 person, 29.4ms
# Speed: 2.4ms preprocess, 29.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
# 저장된 프레임: D:/KHH/team_project/test/test_2_frame_0018.jpg
#
# 0: 640x384 1 person, 31.7ms
# Speed: 2.9ms preprocess, 31.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# 저장된 프레임: D:/KHH/team_project/test/test_2_frame_0019.jpg
#
# 0: 640x384 1 person, 1 clock, 27.4ms
# Speed: 2.5ms preprocess, 27.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
# 저장된 프레임: D:/KHH/team_project/test/test_2_frame_0020.jpg
#
# 0: 640x384 1 person, 33.0ms
# Speed: 3.1ms preprocess, 33.0ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
# 저장된 프레임: D:/KHH/team_project/test/test_2_frame_0021.jpg
#
# 0: 640x384 1 person, 1 cup, 34.4ms
# Speed: 2.9ms preprocess, 34.4ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 저장된 프레임: D:/KHH/team_project/test/test_2_frame_0022.jpg
#
# 0: 640x384 1 person, 30.5ms
# Speed: 2.7ms preprocess, 30.5ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
# 저장된 프레임: D:/KHH/team_project/test/test_2_frame_0023.jpg
#
# 0: 640x384 1 person, 31.1ms
# Speed: 2.6ms preprocess, 31.1ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
# 저장된 프레임: D:/KHH/team_project/test/test_2_frame_0024.jpg
#
# 0: 640x384 1 person, 28.7ms
# Speed: 2.7ms preprocess, 28.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
# 저장된 프레임: D:/KHH/team_project/test/test_2_frame_0025.jpg
#
# 0: 640x384 1 person, 1 clock, 29.5ms
# Speed: 2.5ms preprocess, 29.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
# 저장된 프레임: D:/KHH/team_project/test/test_2_frame_0026.jpg
#
# 0: 640x384 1 person, 1 bottle, 1 clock, 29.2ms
# Speed: 2.2ms preprocess, 29.2ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
# 저장된 프레임: D:/KHH/team_project/test/test_2_frame_0027.jpg
#
# 0: 640x384 1 person, 1 clock, 29.8ms
# Speed: 2.5ms preprocess, 29.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
# 저장된 프레임: D:/KHH/team_project/test/test_2_frame_0028.jpg
#
# 0: 640x384 1 person, 1 bottle, 27.9ms
# Speed: 2.9ms preprocess, 27.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
# 저장된 프레임: D:/KHH/team_project/test/test_2_frame_0029.jpg
#
# 0: 640x384 3 persons, 32.5ms
# Speed: 3.3ms preprocess, 32.5ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
# 저장된 프레임: D:/KHH/team_project/test/test_2_frame_0030.jpg
#
# 0: 640x384 1 person, 1 traffic light, 29.8ms
# Speed: 3.3ms preprocess, 29.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
# 저장된 프레임: D:/KHH/team_project/test/test_2_frame_0031.jpg
#
# 0: 640x384 1 person, 1 traffic light, 30.2ms
# Speed: 2.5ms preprocess, 30.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
# 저장된 프레임: D:/KHH/team_project/test/test_2_frame_0032.jpg

# %%
processor.extract_middle_32_frames("D:/KHH/team_project/test_3.mp4", "D:/KHH/team_project/test/")
# Out:
# 0: 640x384 2 persons, 1 motorcycle, 30.5ms
# Speed: 2.7ms preprocess, 30.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# 사람이 탐지되지 않았습니다.
# 프레임 0002에서 사람이 탐지되지 않았습니다.
#
# 0: 640x384 2 persons, 1 motorcycle, 33.3ms
# Speed: 4.3ms preprocess, 33.3ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
# 저장된 프레임: D:/KHH/team_project/test/test_3_frame_0003.jpg
#
# 0: 640x384 3 persons, 1 motorcycle, 33.0ms
# Speed: 2.6ms preprocess, 33.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 저장된 프레임: D:/KHH/team_project/test/test_3_frame_0004.jpg
#
# 0: 640x384 1 person, 31.7ms
# Speed: 3.0ms preprocess, 31.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
# 저장된 프레임: D:/KHH/team_project/test/test_3_frame_0005.jpg
#
# 0: 640x384 2 persons, 1 backpack, 30.0ms
# Speed: 2.6ms preprocess, 30.0ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
# 저장된 프레임: D:/KHH/team_project/test/test_3_frame_0006.jpg
#
# 0: 640x384 2 persons, 32.0ms
# Speed: 2.7ms preprocess, 32.0ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
# 저장된 프레임: D:/KHH/team_project/test/test_3_frame_0007.jpg
#
# 0: 640x384 2 persons, 33.4ms
# Speed: 2.7ms preprocess, 33.4ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
# 저장된 프레임: D:/KHH/team_project/test/test_3_frame_0008.jpg
#
# 0: 640x384 1 person, 31.6ms
# Speed: 2.4ms preprocess, 31.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# 저장된 프레임: D:/KHH/team_project/test/test_3_frame_0009.jpg
#
# 0: 640x384 1 person, 1 backpack, 32.5ms
# Speed: 3.0ms preprocess, 32.5ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
# 저장된 프레임: D:/KHH/team_project/test/test_3_frame_0010.jpg
#
# 0: 640x384 2 persons, 32.1ms
# Speed: 2.8ms preprocess, 32.1ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
# 저장된 프레임: D:/KHH/team_project/test/test_3_frame_0011.jpg
#
# 0: 640x384 1 person, 32.0ms
# Speed: 3.2ms preprocess, 32.0ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
# 저장된 프레임: D:/KHH/team_project/test/test_3_frame_0012.jpg
#
# 0: 640x384 1 person, 1 backpack, 32.2ms
# Speed: 2.7ms preprocess, 32.2ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
# 저장된 프레임: D:/KHH/team_project/test/test_3_frame_0013.jpg
#
# 0: 640x384 2 persons, 32.9ms
# Speed: 2.8ms preprocess, 32.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
# 저장된 프레임: D:/KHH/team_project/test/test_3_frame_0014.jpg
#
# 0: 640x384 1 person, 53.6ms
# Speed: 4.0ms preprocess, 53.6ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
# 저장된 프레임: D:/KHH/team_project/test/test_3_frame_0015.jpg
#
# 0: 640x384 1 person, 36.8ms
# Speed: 2.5ms preprocess, 36.8ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
# 저장된 프레임: D:/KHH/team_project/test/test_3_frame_0016.jpg
#
# 0: 640x384 1 person, 35.8ms
# Speed: 2.5ms preprocess, 35.8ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 저장된 프레임: D:/KHH/team_project/test/test_3_frame_0017.jpg
#
# 0: 640x384 1 person, 2 skateboards, 36.2ms
# Speed: 3.2ms preprocess, 36.2ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 저장된 프레임: D:/KHH/team_project/test/test_3_frame_0018.jpg
#
# 0: 640x384 1 person, 32.1ms
# Speed: 2.9ms preprocess, 32.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
# 저장된 프레임: D:/KHH/team_project/test/test_3_frame_0019.jpg
#
# 0: 640x384 1 person, 1 backpack, 30.9ms
# Speed: 2.6ms preprocess, 30.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
# 저장된 프레임: D:/KHH/team_project/test/test_3_frame_0020.jpg
#
# 0: 640x384 2 persons, 34.8ms
# Speed: 2.9ms preprocess, 34.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
# 저장된 프레임: D:/KHH/team_project/test/test_3_frame_0021.jpg
#
# 0: 640x384 1 person, 29.7ms
# Speed: 2.7ms preprocess, 29.7ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
# 저장된 프레임: D:/KHH/team_project/test/test_3_frame_0022.jpg
#
# 0: 640x384 2 persons, 28.6ms
# Speed: 2.6ms preprocess, 28.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
# 저장된 프레임: D:/KHH/team_project/test/test_3_frame_0023.jpg
#
# 0: 640x384 1 person, 31.4ms
# Speed: 2.6ms preprocess, 31.4ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
# 저장된 프레임: D:/KHH/team_project/test/test_3_frame_0024.jpg
#
# 0: 640x384 1 person, 1 skateboard, 35.2ms
# Speed: 2.7ms preprocess, 35.2ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
# 저장된 프레임: D:/KHH/team_project/test/test_3_frame_0025.jpg
#
# 0: 640x384 1 person, 31.4ms
# Speed: 2.7ms preprocess, 31.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
# 저장된 프레임: D:/KHH/team_project/test/test_3_frame_0026.jpg
#
# 0: 640x384 1 person, 34.4ms
# Speed: 2.7ms preprocess, 34.4ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
# 저장된 프레임: D:/KHH/team_project/test/test_3_frame_0027.jpg
#
# 0: 640x384 1 person, 34.6ms
# Speed: 2.9ms preprocess, 34.6ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 저장된 프레임: D:/KHH/team_project/test/test_3_frame_0028.jpg
#
# 0: 640x384 1 person, 31.5ms
# Speed: 2.8ms preprocess, 31.5ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
# 저장된 프레임: D:/KHH/team_project/test/test_3_frame_0029.jpg
#
# 0: 640x384 1 person, 1 bench, 31.5ms
# Speed: 2.8ms preprocess, 31.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
# 저장된 프레임: D:/KHH/team_project/test/test_3_frame_0030.jpg
#
# 0: 640x384 1 person, 33.7ms
# Speed: 3.1ms preprocess, 33.7ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
# 저장된 프레임: D:/KHH/team_project/test/test_3_frame_0031.jpg
#
# 0: 640x384 1 person, 1 motorcycle, 32.8ms
# Speed: 5.0ms preprocess, 32.8ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 저장된 프레임: D:/KHH/team_project/test/test_3_frame_0032.jpg
#
# 0: 640x384 1 motorcycle, 27.5ms
# Speed: 2.7ms preprocess, 27.5ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
# 사람이 탐지되지 않았습니다.
# 프레임 0033에서 사람이 탐지되지 않았습니다.

# %%
test_img = cv2.imread("D:/KHH/team_project/test/test_3_frame_0021.jpg", cv2.COLOR_BGR2RGB)

# %%
processor.draw_pose(test_img, processor.detect_pose(test_img))
