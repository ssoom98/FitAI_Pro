# %%
import pandas as pd
from googletrans import Translator

# %%
# 1. CSV 파일 읽기
df = pd.read_csv("data/전처리.csv", encoding="utf-8")

# 2. 데이터 탐색
print(df.info())
print(df.describe())

# 3. 숫자형 컬럼 변환
num_cols = ['1회 섭취량(g)', 'kcal', '탄수화물(g)', '단백질(g)', '지방(g)', '당류(g)']
df[num_cols] = df[num_cols].apply(pd.to_numeric, errors='coerce')

# 4. 결측치 확인 및 처리
print(df.isnull().sum())
df = df.dropna()

# 5. 중복 제거
df = df.drop_duplicates()

# 6. 숫자값 반올림 (예: 소수점 1자리)
df[num_cols] = df[num_cols].round(1)

# 7.고유 식별자 생성 – 예를 들어, 식품종류와 상세분류을 결합
df['고유ID'] = df['식품종류'] + "_" + df['상세분류']

# 8. 필요없는 columns 제거
df = df.drop(['Unnamed: 0', '식품종류', '상세분류'], axis=1)

# 9. column 정렬
df_col = ['고유ID', '식품명', '1회 섭취량(g)', 'kcal', '탄수화물(g)', '단백질(g)', '지방(g)', '당류(g)']
df = df[df_col]

# 10. 전처리 완료된 데이터를 새 CSV로 저장
df.to_csv("data/data1.csv", index=False, encoding="utf-8")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52940 entries, 0 to 52939
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  52940 non-null  int64
#  1   식품종류        52940 non-null  object
#  2   식품명         52940 non-null  object
#  3   상세분류        52940 non-null  object
#  4   1회 섭취량(g)   52940 non-null  float64
#  5   kcal        52940 non-null  object
#  6   탄수화물(g)     52940 non-null  object
#  7   단백질(g)      52940 non-null  object
#  8   지방(g)       52940 non-null  object
#  9   당류(g)       52940 non-null  object
# dtypes: float64(1), int64(1), object(8)
# memory usage: 4.0+ MB
# None
#          Unnamed: 0       1회 섭취량(g)
# count  52940.000000    52940.000000
# mean   26469.500000      378.158917
# std    15282.605962    15055.322609
# min        0.000000        0.030000
# 25%    13234.750000       70.000000
# 50%    26469.500000      100.000000
# 75%    39704.250000      189.000000
# max    52939.000000  1000000.000000
# Unnamed: 0       0
# 식품종류             0
# 식품명              0
# 상세분류             0
# 1회 섭취량(g)        0
# kcal           923
# 탄수화물(g)       9253
# 단백질(g)        2754
# 지방(g)         9506
# 당류(g)         2024
# dtype: int64

# %%
df.head()
# Out:
#        고유ID   식품명  1회 섭취량(g)   kcal  탄수화물(g)  단백질(g)  지방(g)  당류(g)
# 0   음식_육류구이  꿩불고기      500.0  368.8     39.7    33.5    8.5   16.9
# 1   음식_육류구이   닭갈비      400.0  595.6     44.9    45.9   25.8   21.2
# 2   음식_육류구이   닭갈비      300.0  558.5     23.1    45.5   31.6    8.5
# 3   음식_육류구이   닭꼬치       70.0  176.7     13.3    11.6    8.6    3.2
# 4  음식_채소류구이  더덕구이      100.0  184.0     31.1     3.1    5.2   11.6

# %% [markdown]
# # json file data 정리

# %%
# json 전처리 data read
food_json = pd.read_csv('data/json_food_data.csv')
print(food_json.head())
# Out:
#              Code Name              식품명  1회 섭취량(g)  당류(g)
# 0  B020401XX_00865.jpg  bltsaendeuwichi        NaN    NaN
# 1  B020401XX_00866.jpg  bltsaendeuwichi        NaN    NaN
# 2  B020401XX_00866.jpg  bltsaendeuwichi        NaN    NaN
# 3  B020401XX_00867.jpg  bltsaendeuwichi        NaN    NaN
# 4  B020401XX_00867.jpg  bltsaendeuwichi        NaN    NaN

# %%
food_json.shape

# %%
# 두파일 coloumns 확인
# 기존 음식 data
print(df.columns)
print()
# json 파일 data
print(food_json.columns)
# Out:
# Index(['고유ID', '식품명', '1회 섭취량(g)', 'kcal', '탄수화물(g)', '단백질(g)', '지방(g)',
#        '당류(g)'],
#       dtype='object')
#
# Index(['Code Name', '식품명', '1회 섭취량(g)', '당류(g)'], dtype='object')

# %%
import pandas as pd
import time
from googletrans import Translator

# 1️⃣ 데이터 로드
json_food_df = pd.read_csv("data/json_food_data.csv")

# 2️⃣ 'Code Name' 컬럼 제거
json_food_df = json_food_df.drop(columns=["Code Name"], errors="ignore")

# 3️⃣ 중복 제거 (고유한 식품명만 추출)
unique_food_names = json_food_df["식품명"].dropna().unique()

# 4️⃣ 번역기 객체 생성
translator = Translator()

# 5️⃣ 영어식품명 → 한글 변환 함수
def translate_text(text):
    try:
        if not isinstance(text, str) or text.strip() == "":  # 빈 값 체크
            return text
        translated = translator.translate(text, src='en', dest='ko')  # 번역 실행
        time.sleep(1)  # Google API 차단 방지
        return translated.text
    except Exception as e:
        print(f"⚠️ 번역 오류: {text} - {e}")
        return text  # 오류 발생 시 원본 반환

# 6️⃣ 중복 없는 데이터만 번역
translated_dict = {name: translate_text(name) for name in unique_food_names}

# 7️⃣ 원본 데이터에 번역된 값 적용
json_food_df["식품명"] = json_food_df["식품명"].map(translated_dict)

# 8️⃣ 저장
json_food_df.to_csv("json_food_data_translated.csv", index=False, encoding="utf-8-sig")
print("✅ 번역 완료: json_food_data_translated.csv 저장 완료")
# Out:
# ✅ 번역 완료: json_food_data_translated.csv 저장 완료

# %%
jfdt = pd.read_csv('json_food_data_translated.csv')
jfdt
# Out:
#                      식품명  1회 섭취량(g)  당류(g)
# 0        Bltsaendeuwichi        NaN    NaN
# 1        Bltsaendeuwichi        NaN    NaN
# 2        Bltsaendeuwichi        NaN    NaN
# 3        Bltsaendeuwichi        NaN    NaN
# 4        Bltsaendeuwichi        NaN    NaN
# ...                  ...        ...    ...
# 3133526          Huinjug        NaN    NaN
# 3133527          Huinjug        NaN    NaN
# 3133528          Huinjug        NaN    NaN
# 3133529          Huinjug        NaN    NaN
# 3133530          Huinjug        NaN    NaN
#
# [3133531 rows x 3 columns]

# %%
unique_food_names
# Out:
# array(['bltsaendeuwichi', 'galaetteog', 'galibi', 'gaji', '가지',
#        'gacheudong', 'ganjang', 'galbigu-i', 'galbijjim', 'galbitang',
#        'gam', 'tangerine_juice', 'gamjagu-i', 'gamjageulatang',
#        'gamjabokk-eum', 'gamjasaelleodeu', 'gamjaseupeu', 'potato_soup',
#        'potato_chips', 'gamjachib', 'french_fries', 'gamjatwigim',
#        'geobongpodo', 'geonjadu', 'geonkeulaenbeli', 'geonpodo',
#        'gemas-sal', 'gejang', 'gyeojasoseu', 'mustard_sauce', 'gyeongdan',
#        'gogalbi', 'goguma', 'gungoguma', 'mackerel', 'godeung-eo',
#        'godeung-eogu-i', 'goloke', 'goleugonjolla', 'goleugonjollapija',
#        'gochu', 'chili', 'gochujang', 'gochujang-ajji', 'gochusgalu',
#        'goldkiwi', 'gobchangjeongol', 'gojgam', 'gwailjuseu',
#        'gwailchaesosaelleodeu', 'fruit_vegetable_salad', 'guaba', 'guava',
#        'gugsu', 'gughwacha', 'gunmandu', 'gunbam', 'gyul', 'geulatang',
#        'geulin-ollibeu', 'gim', 'gimgu-i', 'gimmakki', 'gimbab',
#        'gimchigug', 'gimchibokk-eumbab', 'gimchijjigae', 'kkaleubonala',
#        'kkamangbeleuchijeu', 'kkanpung-gi', 'kkeom', 'cockle', 'kkul',
#        'nagasakkijjamppong', 'nasigolaeng', 'nagjibokk-eum', 'natto',
#        'naengmyeon', 'naengchaejogbal', 'nolangpapeulika',
#        'nogsaegpimang', 'nogjeub', 'nutella', 'neutalibeoseos', 'kelp',
#        'dakeuchokollis', 'dangam', 'danhobag', 'egg', 'dalgyalmal-i',
#        'dalgyalbokk-eumbab', 'dalgyalbibimbab', 'dalgyalsaendeuwichi',
#        'dalgyaljjim', 'dalgyalhulai', 'dalg-gaseumsal', 'chicken_breast',
#        'dalg-gaseumsalgu-i', 'dalg-gaseumsalsaelleodeu',
#        'chicken_breast_caesar_salad', 'dalg-gaseumsalsijeosaelleodeu',
#        'dalg-galbi', 'dalg-galbigu-i', 'dalg-gangjeong', 'dalg-gogi',
#        'dalg-gogibokk-eum', 'dalgnalgae', 'dalgnalgaeyangnyeomgu-i',
#        'dalgbal', 'dalgsalchaesodubanjangbokk-eum',
#        'stir_fried_chicken_vegetables_and_soy_sauce',
#        'dalgsalchaesobokk-eum', 'dalgjjim', 'dalgpapeulikabokk-eum',
#        'dalghunjegu-i', 'dang-geun', 'dang-geunjuseu', 'dang-geunkeikeu',
#        'daechu', 'daepa', 'teriyaki_chicken', 'dechindubu', 'doneos',
#        'dolia', 'dolayakki', 'steamed_pork_ribs', 'dwaejigamja',
#        'dwaejigogigochujangbulgogi', 'grilled_pork', 'dwaejigogigu-i',
#        'dwaejigogibokk-eum', 'dwaejigogiseuteikeu', 'doenjang-gug',
#        'doenjangjjigae', 'bean_curd', 'dubutwigim', 'duyu',
#        'deungsimseuteikeu', 'dimseom', 'dimsum', 'ttalgi', 'ttalgilatte',
#        'ttalgiaiseukeulim', 'strawberry_ice_cream', 'ttangkongbeoteo',
#        'tteoggalbi', 'tteoggug', 'tteogmandugug,gogimandu', 'tteogbokk-i',
#        'ttom-yangkkung', 'lattattu-i', 'latte', 'lamen', 'noodles',
#        'lasanya', 'lajanya', 'labseuta', 'ledeuwain', 'lemoneideu',
#        'lemon', 'lomeinsangchu', 'lol', 'rollcake', 'lijotto',
#        'ricotta_cheese', 'ma', 'maneul', 'maneulgu-i', 'maneuljang-ajji',
#        'madeullen', 'maleugelittapija', 'margherita pizza',
#        'maleun-ojing-eo', 'marshmallow', 'mayonejeu',
#        'makalonisaelleodeu', 'makalong', 'matecha', 'maggeolli',
#        'a_lollipop', 'mandu', 'dumpling', 'mandugug', 'mango', 'mang-go',
#        'maesil', 'maegju', 'muffin', 'meopin', 'memil',
#        'maeswideupoteito', 'mellon', 'myeonglanjeos', 'modeumchobab',
#        'modeumtwigim', 'modeumhoe', 'mojjalellachijeu', 'mugimchi', 'muu',
#        'octopus', 'mulmiyeog', 'myujeulli', 'misolamen', 'misojang-gug',
#        'miyeoggug', 'miyeognamul', 'meatball', 'milgam',
#        'milkeuchokollis', 'bageteuppang', 'banana', 'bananauyu',
#        'bananachib', 'banillaaiseukeulim', 'balamtteog', 'babekyuchikin',
#        'bajil', 'bam', 'bab', 'bang-ultomato', 'baechu', 'baechugimchi',
#        'baegdo', 'baeghyang-gwa', 'beoseos', 'beoseos_jang-ajji',
#        'beoseos-jang-ajji', 'beoteo', 'beoteokuki', 'beondegi', 'beigeul',
#        'beigeulsaendeuwichi', 'beikeon', 'beikeongu-i', 'beikeonpija',
#        'bodeuka', 'bolippang', 'bossam', 'boicha', 'bogsung-a', 'peach',
#        'bokk-eun-wondu', 'bokk-eummyeon', 'bokk-eumbab',
#        'bokk-eumssalgugsu', 'bong-gollepaseuta', 'budaejjigae',
#        'korean_style_pancake', 'bug-eogug',
#        'bulg-eun yangbaechu jeol-imv', 'bung-eoppang', 'brownie',
#        'beulajilneoteu', 'beulokolligyelanjjim', 'beulokolli',
#        'beullaegkeopi', 'beullubeli', 'bibimgugsu', 'bibimnaengmyeon',
#        'bibimbap', 'bibimbab', 'biennasosiji', 'vienna_sausage', 'ppang',
#        'ppeongtwigi', 'sagwa', 'apple', 'sagwasaelleodeu', 'apple_juice',
#        'sagwajuseu', 'sagwapai', 'saida', 'satang', 'santtalgi',
#        'apricot', 'salgu', 'salsasoseu', 'boiled_sweet_potatoes',
#        'salm-eundalgyal', 'samgyeobsal', 'samgyeobsalgu-i', 'samgyetang',
#        'sangchu', 'sangchusaelleodeu', 'saessagsaelleodeu', 'saeu',
#        'shrimp', 'saeugu-i', 'shrimp_dim_sum', 'saeumandu',
#        'saeumaeuntang', 'spicy_shrimp_soup', 'saeubokk-eumbab',
#        'saeutwigim', 'saendeuwichi', 'sandwic', 'selleoli',
#        'saeng-gangcha', 'saeng-gwailjuseu', 'saengmaegju', 'roasted_fish',
#        'saengseongu-i', 'saengseonjjigae', 'saengseonchobab',
#        'saengseontwigim', 'saengseonhoe', 'sashimi', 'saengkeulim',
#        'saengkeulimkeikeu', 'seoglyu', 'seoltang', 'senbei',
#        'sogogiyugpo', 'sogeum', 'somyeon', 'sosiji', 'sosijigu-i',
#        'somsatang', 'songpyeon', 'a_beef_dish', 'sogogigu-i',
#        'soegogibokk-eum', 'subag', 'subagjuseu', 'sugjunamul', 'sundae',
#        'sundaegugbab', 'sundaebokk-eum', 'sundubujjigae',
#        'sunsaljjimdalg', 'sunsalchikin', 'shake', 'sweikeu', 'syukeulim',
#        'scrambled_egg', 'seukeulaembeuldeuegeu', 'seuteikeu', 'seutyu',
#        'seuteulingchijeu', 'seupageti', 'seupagetimyeon', 'soup',
#        'seupeu', 'seullaiseuchijeu', 'sigeumchi', 'sileob', 'syrup',
#        'silutteog', 'silieol', 'silieolba', 'sijeosaelleodeu', 'rice',
#        'ssal', 'ssalgwaja', 'ssalgugsu', 'ssalbab', 'agwijjim',
#        'flaxseed', 'amondeu', 'abokado', 'abokadosaelleodeu',
#        'avocado_salad', 'aseupalageoseugu-i', 'aseupalageoseubokk-eumbab',
#        'aori_apple', 'aolisagwa', 'aiseulatte', 'ice_coffee',
#        'aiseukeopi', 'aiseukeulim', 'iced tea', 'apogato',
#        'ansimseuteikeu', 'tenderloin steak', 'allo-ejuseu', 'albab',
#        'altaligimchi', 'aepeulminteu', 'aehobag', 'squash',
#        'aegsang-yoguleuteu', 'aengdu', 'yakkisoba', 'yachaebokk-eum',
#        'yangkkochi', 'yangnyeomchikin', 'yangbaechu',
#        'yangbaechusaelleodeu', 'yangbaechussam', 'yangbaechujeol-im',
#        'yangsangchusaelleodeu', 'yangju', 'yangpa', 'onion_salad',
#        'yangpasaelleodeu', 'yangpatwigim', 'eomuggug', 'eomugtang',
#        'eoyugsosiji', 'egeutaleuteu', 'yeongeun', 'grilled_salmon',
#        'yeon-eogu-i', 'yeon-eolol', 'salmon_salad', 'yeon-eosaelleodeu',
#        'salmon_sushi', 'yeon-eochobab', 'yeon-eohoe', 'mulberry', 'odi',
#        'olenji', 'olenjijuseu', 'oligu-i', 'oliloseugu-i', 'omeulaiseu',
#        'omeulles', 'omija', 'grilled_oven_chicken_body',
#        'obeungu-ichikinmomtong', 'oi', 'oigimchi', 'oisaelleodeu',
#        'oipikeul', 'ojing-eo', 'ojing-eotwigim', 'okonomiyakki',
#        'oteumil', 'ogsususeupeu', 'wasabi', 'wain', 'wapeul', 'wantang',
#        'wangdongaseu', 'wangmandu', 'yoguleuteu', 'udong', 'uyu', 'yugwa',
#        'yuja', 'yugpo', 'yughoe', 'yughoebibimbab', 'eunhaeng', 'insam',
#        'plum', 'jamong', 'jamongjuseu', 'jabgogsigppang', 'jabchae',
#        'jas', 'jang-eogu-i', 'rice eel topping', 'jang-eochobab',
#        'jeog-yangbaechu', 'jeonbog', 'jeol-imbaechu', 'jelli', 'jomigim',
#        'jogbal', 'jumeogbab', 'juseu', 'jug', 'jjajangmyeon', 'jjamppong',
#        'bread_and_jam', 'jjaemppang', 'jjoggalbigu-i', 'jjukkumibokk-eum',
#        'steamed_buns', 'sesame_seeds', 'chamkkae', 'cham-oe',
#        'chamchisaendeuwichi', 'canned_tuna', 'chamchitongjolim',
#        'tuna_sashimi', 'chabssaltteog', 'chaesojuseu', 'chaesojug',
#        'cheondobogsung-a', 'cheongpodo', 'chedachijeu', 'cheli', 'chobab',
#        'sushi', 'chokomeopin', 'chokoba', 'chokoaiseukeulim', 'chokouyu',
#        'chocolate_cake', 'chokokugi', 'chocolate_cookies', 'chokollis',
#        'chueotang', 'chungwon', 'chinese_spring_rolls', 'chyuleoseu',
#        'chijeu', 'cheese', 'cheese_ball', 'chijeubol', 'chijeuppang',
#        'cheese_sticks', 'chijeupija', 'cheese_pizza', 'chikeoli',
#        'chikin', 'chikinneoges', 'chikinseuteikeu', 'chikinkale',
#        'chillisoseu', 'kanape', 'kaeleomael', 'kalelaiseu', 'kalesoseu',
#        'kakaonibseu', 'kapelatte', 'kapemoka,hwipingkeulim', 'kapuchino',
#        'caprese_salad', 'kapeulejesaelleodeu', 'kaeleomelmakkiatto',
#        'kaesyuneos', 'kaelliponialol', 'keoseuteodeukeulim', 'keopi',
#        'keoblamyeon', 'keikeu', 'keil', 'ketchup', 'kecheob', 'kokoa',
#        'cocoa', 'kollabi', 'kombineisyeonpija', 'kong-gugsu', 'kongnamul',
#        'kongsaelleodeu', 'cookie', 'kwesadia', 'keulaekeo', 'keulaenbeli',
#        'crepre', 'keulepe', 'croissant', 'keulowasang', 'keulimchijeu',
#        'cream_cheese', 'keulimpaseuta', 'kiwi', 'takoyaki', 'soda',
#        'tomato', 'tomatosaelleodeu', 'tomatojuseu', 'tomatopaseutasoseu',
#        'toast', 'chicken', 'tongmilppang', 'tilamisu', 'panini', 'padark',
#        'paseuta', 'paseulli', 'pain-aepeul', 'pajeon', 'papaya',
#        'papeulika', 'pepenoni gialli', 'papeulika,ppalgang', 'popcorn',
#        'pastai', 'pat', 'patbingsu', 'patjug', 'paeng-ibeoseos',
#        'pepeolonipija', 'pennepaseuta', 'podo', 'pork_rib', 'poglib',
#        'pyogobeoseos', 'puding', 'pusgochu', 'peulejeul',
#        'peulenchitoseuteu', 'pimang', 'piseutachio', 'pija', 'pikan',
#        'hawaianpija', 'hanlabong', 'hallapinyo', 'hallapinyopikeul',
#        'hambagseuteikeu', 'hasdogeu', 'has-soseu', 'has-wing',
#        'hot_chocolate', 'haschoko', 'haskeikeu', 'haemuldeopbab',
#        'haemulbokk-eum', 'haemuljjim', 'haemultang', 'haebalagissi',
#        'sunflower_seeds', 'haesam', 'haeswibeulaun', 'haejang-gug', 'ham',
#        'haembokk-eumbab', 'ham_sandwich', 'haemchijeusaendeuwichi',
#        'hodu', 'hodupai', 'homilppang', 'hobagssi', 'black_tea',
#        'hwadeogpija', 'white_wine', 'hoeoligamja', 'hulaideuchikin',
#        'hulaideuchikin, nalgae', 'fried_chicken_drumstick',
#        'hulangkeusosiji', 'frenchfries', 'pepper', 'hunjeyeon-eo',
#        'hunje-oli', 'hunje-olisaelleodeu', 'hunjechikin', 'huinjug',
#        'grilled_pork_belly'], dtype=object)

# %%
jfdt['식품명'].dropna().unique()
# Out:
# array(['Bltsaendeuwichi', 'Galaetteog', '갈리비', '가지', 'Gacheudong', '간장',
#        'Galbigu-i', '갈비함', '갈비당', '게임', 'Tangerine_juice', 'Gamjagu-i',
#        'Gamjageulatang', 'gamjabokk-eum', 'gamjasaelleodeu',
#        'Gamjaseupeu', 'patato_soup', 'patato_chips', 'Gamjachib', '프랑스어',
#        'gamjatwigim', 'Geobongpodo', 'genjadu', 'geonkeulaenbeli',
#        'geonpodo', 'Gemas-sal', '제정', 'Gyeojasoseu', '머스타드 _sauce',
#        'Gyeongdan', 'Gogalbi', 'Goguma', 'Gungoguma', '고등어', 'Godeung-eo',
#        'Godeung-Eogu-i', '골로크', 'Goleugonjolla', 'goleugonjollapija',
#        '고쿠', '칠리', '고추 장', 'Gochujang-Ajji', 'GOCHUSGALU', 'Goldkiwi',
#        'GOBCHANGJEONGOL', 'gojgam', 'Gwailjuseu', 'Gwailchaesosaelleodeu',
#        'fruit_vegetable_salad', '구아바', '구그수', '구르와 차', '건만두', '건 햄',
#        'Gyul', 'Geulatang', 'Geulin-Ollibeu', '김', 'Gimgu-i', 'Gimmakki',
#        '짐바브', 'Gimchigug', 'Gimchibokk-Eumbab', 'Gimchijjigae',
#        'KKALEUBOLANA', 'Kkamangbeleuchijeu', 'Kkanpung-Gi', 'KKEOM',
#        '조가비', 'Kkul', 'Nagasakkijamppong', 'Nasigolaeng', 'Nagjibokk-Eum',
#        'Natto', 'Naengmyeon', 'Naengchaejogbal', 'Nolangpapeulika',
#        'Nogsaegpimang', 'nogjeub', '누 텔라', '중성 분석', '켈프', '다케 우코 콜리스',
#        'Dangam', 'Danhobag', '계란', 'Dalgyalmal-i', 'Dalgyalbokk-eumbab',
#        'Dalgyalbibimbab', 'Dalgyalsaendeuwichi', 'Dalgyaljjim',
#        'Dalgyalhulai', 'Dalg-Gaseumsal', 'Chicken_brest',
#        'Dalg-gaseumsalgu-i', 'Dalg-gaseumsalsaelleodeu',
#        'chicken_breast_caesar_salad', 'dalg-gaseumsalsijeosaelleodeu',
#        '달그-갈비', 'Dalg-Galbigu-i', 'Dalg-gangjeong', 'Dalg-gogi',
#        'Dalg-Gogibokk-Eum', 'Dalgnalgae', 'Dalgnalgaeyangnyeomgu-i',
#        '달그 발', 'Dalgsalchaesodubanjangbokk-eum',
#        'stir_fried_chicken_vegetables_and_soy_sauce',
#        'Dalgsalchaesobokk-eum', 'Dalgjjim', 'dalgpapeulikabokk-eum',
#        'Dalghunjegu-i', '댄 대우', 'Dang-Geunjuseu', 'Dang-Geunkeikeu',
#        '다체 쿠', 'Daepa', 'Teriyaki_chicken', '데신 두부', 'doneos', '돌리아',
#        'Dolayakki', 'steamed_pork_ribs', 'dwaejigamja',
#        'dwaejigogigochujangbulgogi', 'grill_pork', 'dwaejigogigu-i',
#        'dwaejigogibokk-eum', 'dwaejigogiseuteikeu', 'Doenjang-gug',
#        '도언 얀지가', 'bean_curd', 'Dubutwigim', 'duyu', 'Deungsimseuteikeu',
#        'Dimseom', '딤섬', 'ttalgi', 'ttalgilatte', 'ttalgiaiseukeulim',
#        'Strawberry_ice_cream', 'Ttangkongbeoteo', 'Tteokgalbi',
#        'tteoggug', 'Tteogmandugug, Gogimandu', 'Tteokbokki',
#        'Tom-Yang Kung', 'Lattattu-i', '라떼', '라멘', '국수', '라사 사냐',
#        'Lajanya', 'labseuta', 'Ledeuwain', 'Lemoneideu', '레몬',
#        'Lomeinsangchu', 'ㅋㅋㅋ', '롤 케이크', '리 조토', 'Ricotta_cheese', '엄마',
#        '갈레', 'Maneulgu-i', 'Maneuljang-Ajji', 'Madeullen',
#        'Maleugelittapija', '마르게리타 피자', 'Maleun-Ojing-eo', '마시멜로',
#        'Mayonejeu', 'Makalonisaelleodeu', '마 칼롱', '마테카', 'Makgeolli',
#        'a_lollipop', '만두', '심', 'Mandugug', '망고', 'Mang-Go', 'Maesil',
#        'Maegju', '머핀', 'Meopin', '밈', 'Maeswideupoteito', '멜론',
#        'myeonglanjeos', 'modeumchobab', 'modeumtwigim', 'modeumhoe',
#        'Mojjalellachijeu', 'Mugimchi', '무우', '문어', 'mulmiyeog',
#        'myujeulli', '불신', 'Misojang-gug', '미에오 구그', '미인 주민', '미트볼',
#        'Milgam', 'Milkeuchokollis', 'Bageteuppang', '바나나', '바나 나우',
#        '바나나 칩', 'Banillaiiseukeulim', 'Balamtteog', 'Babekyuchikin', '바질',
#        'BAM', '밥', 'Bang-ultomato', '바체 쿠', 'Baechugimchi', '바그도',
#        '베르양 가와', 'BESEOS', 'BESEOS_JANG-AJJI', 'BESEOS-JANG-AJJI',
#        'Beoteo', 'Beoteokuki', 'Beondegi', '베일', '베이지 울 사엔데 우치',
#        'Beikeon', 'Beikeongu-i', 'Beikeonpija', 'Bodeuka', '볼리 팡', '보자',
#        '보이카', 'Bogsung-A', '복숭아', 'Bokk-Eun-Wondu', 'Bokkeummyeon',
#        '책-야 햄브', 'Book-Eumss Gugsu', 'Bong-Gollepaseuta', 'Budaejjigae',
#        'Korean_style_pancake', '버그에 오그', 'Bulg-Eun Yangbaechu Jeol-Imv',
#        'Bungeoppang', '브라우니', 'Beulajilneoteu', 'BEULOKOLLIGYELANJIM',
#        'Beulokolli', 'Beullaegkeopi', 'Beullubeli', 'Bibim Guksu',
#        'Bibim Naengmyeon', 'Bibimbap', '비킴 바브', 'Biennasosiji',
#        'Vienna_sausage', 'Ppang', 'ppeongtwigi', '사그와', '사과',
#        'Sagwasaelleodeu', 'apple_juice', 'Sagwajuseu', 'Sagwapai', '상세',
#        '사탕', '산 틀기', '살구', '살사 소스', 'boomed_sweet_potatoes',
#        'salm-eundalgyal', 'Samgyeobsal', 'Samgyeobsalgu-i', 'Samgyetang',
#        '산 쿠', 'Sangchusaelleodeu', 'Saessagsaelleodeu', '사에', '새우',
#        'Saeugu-i', '새우 _dim_sum', 'Saeumandu', 'Saeumaeuntang',
#        'spicy_shrimp_soup', 'Saeubokk-eumbab', 'Saeu Twigim',
#        'Saendeuwichi', '샌드위치', '셀레 올리', 'Saeng-gangcha',
#        'Saeng-gwailjuseu', 'Saengmaegju', '로스트 _fish', 'Saengseongu-i',
#        'Saengseonjjigae', 'Saengseonchobab', 'Saengseon Twigim',
#        'Saengseonhoe', '사시미', 'Saengkeulim', 'Saengkeulimkeikeu',
#        '시 글리 우', 'Seoltang', '센 베이', 'Sogogiyugpo', '소기', '머시온', '소시 지',
#        'Sosijigu-i', '솜 사탕', '송 비온', 'A_BEEF_DISH', 'Sogogigu-i',
#        'Soegogibokk-Eum', '서브 그', 'Subagjuseu', '수주 말', '순대',
#        'Sundaegugbab', 'Sundaebokk-Eum', 'Sundubu Jjigae',
#        'Sunsaljjimdalg', 'Sunsalchikin', '떨림', 'Sweikeu', 'Syukeulim',
#        '스크램블 _egg', 'Seukeulaembeuldeuegeu', 'seuteikeu', 'Seutyu',
#        'Seuteulingchijeu', 'Seupageti', 'Seupagetimyeon', '국', 'SEUPEU',
#        'Seullaiseuchijeu', 'Sigeumchi', 'Sileob', '시럽', 'Silutteog',
#        '실리올', '실리올바', 'sijeosaelleodeu', '쌀', 'SSAL', 'Ssalgwaja',
#        'Ssalgugsu', 'Ssalbab', 'Agwijjim', '아마씨', '아몬데', 'abokado',
#        'Abokadosaelleodeu', 'avocado_salad', 'Aseupalageoseugu-i',
#        'Aseupalageoseubokk-eumbab', 'aori_apple', 'AOLISAGWA',
#        'aiseulatte', 'Ice_coffee', 'Aiseukeopi', 'Aiseukeulim', '아이스 티',
#        '아보가토', 'ansimseuteikeu', '안심 스테이크', 'Allo-Ejuseu', 'albab',
#        'Altaligimchi', 'Aepeulminteu', 'aehobag', '스쿼시',
#        'Aegsang-Yoguleuteu', 'Aengdu', '야키소바', 'Yachaebokk-Eum', '양고치',
#        '양니 옴 치킨', '양 바체 쿠', '양바 에쿠사 엘로 데루', '양 바초 햄', '양바체 쿠 제올-임',
#        '양 산 쿠사 젤로 로데 우', '양주', '양파', 'Onion_salad', 'Yangpasaelleodeu',
#        'Yangpatwigim', 'eomuggug', 'Eomugtang', 'Eoyugsosiji',
#        'Egeutaleuteu', '윤전', 'grille_salmon', '연인-에오구 -I', '이온에 올롤',
#        'salmon_salad', '이온-에오 사 셀로 데우', 'salmon_sushi', '연-에코 코브',
#        '이온 에호', '짙은 적자색', 'ODI', '올렌 지', 'Olenjijuseu', '올리고 -I',
#        'Olilosugu-i', '오메일 라 세', '오메 룰레스', '오미자',
#        'grill_oven_chicken_body', 'Obeungu-ichikinmomtong', '오이', '오이임 치',
#        'Oisaelleodeu', 'Oipikeul', '오징-에오', '오지-otwigim', 'Okonomiyaki',
#        'Oteumil', 'OGSUSUSEUPEU', '와사비', '광차', 'Wapeul', 'Wantang',
#        'Wangdongaseu', '왕만두', 'yoguleuteu', '우동', 'uyu', '유그와', '유자',
#        '유포', 'Yughoe', '유기 비비 바브', '유하 엔', 'inam', '자두', 'Jamong',
#        'Jamongjuseu', 'jabgogsigppang', 'japchae', 'Jas', '장-에오구 -I',
#        '쌀 장어 토핑', '장 에오 코브 브', 'Jeog-Yangbaechu', 'JeonBog',
#        'Jeol-Imbaechu', '젤리', '조미킴', '조그 발', 'Jumeogbab', 'Juseu', '조끼',
#        'jjajangmyeon', 'jjamppong', 'bread_and_jam', 'jjaemppang',
#        'jjoggalbigu-i', 'jjukkumibokk-eum', 'steamed_buns',
#        'sesame_seeds', 'Chamkkae', 'Cham-oe', 'Chamchisaendeuwichi',
#        'canned_tuna', 'Chamchitongjolim', 'tuna_sashimi', 'Chabssaltteog',
#        'Chaesojuseu', '차에 소그', 'Cheondobogsung-A', '청도도', '체데 다치 제우',
#        '첼리', '초밥', '초코 코노 핀', '초코바', 'Chokoaiseukeulim', '초쿠유',
#        '초콜릿 _cake', '초코쿠기', '초콜릿_cookies', 'chokollis', 'chueotang', '정복',
#        '중국어 _spring_rolls', 'Chyuleoseu', 'Chijeu', '치즈', '치즈 _ball',
#        'Chijeubol', 'Chijeuppang', '치즈 _sticks', 'Chijeupija',
#        '치즈 _pizza', 'Chikeoli', 'Chikin', 'Chikinneoges',
#        'Chikinseuteikeu', 'Chikinkale', 'chillisoseu', '카나페',
#        'Kaeleomael', '칼 렐라 이사', '칼레소스', '카카 오 닙스', 'Kapelatte',
#        '카페모카, hwipingkeulim', '카푸치노', 'Caprese_salad',
#        'Kapeulejesaelleodeu', 'Kaeleomelmakkiatto', 'Kaesyuneos',
#        'Kaelliponialol', 'keoseuteodeukeulim', 'KEOPI', 'Keoblamyeon',
#        'KEIKEU', '킬', '케첩', '케체브', '코코아', '콜라비', 'kombineisyeonpija',
#        '콩 구아수', 'Kongnamul', 'Kongsaelleodeu', '매력적인 여자', 'Kwesadia',
#        'Keulaekeo', 'Keulaenbeli', '크레 파', 'Keupe', '크로와상', 'Keulowasang',
#        'Keulimchijeu', '크림 _cheese', 'Keulimpaseuta', '키위', '타카 요키', '소다',
#        '토마토', 'Tomatosaelleodeu', '토마토 주세', 'tomatopaseutasoseu', '토스트',
#        '닭', 'Tongmilppang', '틸라미수', '파니니', 'Padark', 'Paseuta',
#        'Paseulli', '고통에 대한', '페준', '파파야', 'Papeulika', 'Pepenoni Gialli',
#        'Papeulika, ppalgang', '팝콘', 'Pastai', '가볍게 두드리기', 'Patbingsu',
#        'Patjug', 'Paeng-Ibeoseos', 'Pepeolonipija', 'Pennepaseuta', '포도',
#        'pork_rib', 'Poglib', 'pyogobeoseos', '푸딩', 'Pusgochu',
#        'Peulejeul', 'peulenchitoseute', '피방', 'Piseutachio', '피자', '피칸',
#        'Hawaianpija', '한라봉', '할라피니오', 'Hallapinyopikeul', '햄마 슈테 리우',
#        'Hasdogeu', 'has-soseu', 'Has-Wing', 'HOT_CHOCOLATE', 'Haschoko',
#        'Haskeikeu', 'Haemuldeopbab', 'Haemulbokk-Eum', 'haemuljjim',
#        'haemultang', 'Haebalagissi', 'Sunflower_seeds', '하삼',
#        'Haeswibeulaun', 'Haejang-gug', '햄', 'Haembokk-eumbab',
#        'ham_sandwich', 'Haemchijeusaendeuwichi', '호두', 'Hodupai',
#        'Homilppang', 'Hobagssi', 'black_tea', 'Hwadeogpija', 'White_wine',
#        'Hoeoligamja', 'Hulaideuchikin', 'Hulaideuchikin, nalgae',
#        'fried_chicken_drumstick', 'Hulangkeusosiji', '감자 튀김', '후추',
#        'Hunjeeon-eo', '훈제-올리', 'HUNJE-OLISAELLEODEU', 'Hunjechikin',
#        'Huinjug', 'grill_pork_belly'], dtype=object)
